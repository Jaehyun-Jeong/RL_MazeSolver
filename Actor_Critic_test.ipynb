# %%
import sys
import torch  
import gym
import numpy as np  
import torch.nn as nn
import torch.optim as optim
import torch.nn.functional as F
from torch.autograd import Variable
import matplotlib.pyplot as plt
import pandas as pd

# hyperparameters
hidden_size = 256
learning_rate = 3e-4

# Constants
GAMMA = 0.99
num_steps = 300
max_episodes = 3000

# %%
class ActorCritic(nn.Module):
    def __init__(self, num_inputs, num_actions, hidden_size, learning_rate=3e-4):
        super(ActorCritic, self).__init__()

        self.num_actions = num_actions
        self.critic_linear1 = nn.Linear(num_inputs, hidden_size)
        self.critic_linear2 = nn.Linear(hidden_size, 1)

        self.actor_linear1 = nn.Linear(num_inputs, hidden_size)
        self.actor_linear2 = nn.Linear(hidden_size, num_actions)
    
    def forward(self, state):
        state = Variable(torch.from_numpy(state).float().unsqueeze(0))
        value = F.relu(self.critic_linear1(state))
        value = self.critic_linear2(value)
        
        policy_dist = F.relu(self.actor_linear1(state))
        policy_dist = F.softmax(self.actor_linear2(policy_dist), dim=1)

        return value, policy_dist

# %%
def a2c(env):
    num_inputs = env.observation_space.shape[0]
    num_outputs = env.action_space.n
    
    actor_critic = ActorCritic(num_inputs, num_outputs, hidden_size)
    ac_optimizer = optim.Adam(actor_critic.parameters(), lr=learning_rate)

    all_lengths = []
    average_lengths = []
    all_rewards = []
    entropy_term = 0

    for episode in range(max_episodes):
        log_probs = []
        values = []
        rewards = []

        state = env.reset()
        for steps in range(num_steps):
            value, policy_dist = actor_critic.forward(state)
            value = value.detach().numpy()[0,0]
            dist = policy_dist.detach().numpy()

            action = np.random.choice(num_outputs, p=np.squeeze(dist))
            log_prob = torch.log(policy_dist.squeeze(0)[action])
            entropy = -np.sum(np.mean(dist) * np.log(dist))
            new_state, reward, done, _ = env.step(action)

            rewards.append(reward)
            values.append(value)
            log_probs.append(log_prob)
            entropy_term += entropy
            state = new_state
            
            if done or steps == num_steps-1:
                Qval, _ = actor_critic.forward(new_state)
                Qval = Qval.detach().numpy()[0,0]
                all_rewards.append(np.sum(rewards))
                all_lengths.append(steps)
                average_lengths.append(np.mean(all_lengths[-10:]))
                if episode % 10 == 0:                    
                    sys.stdout.write("episode: {}, reward: {}, total length: {}, average length: {} \n".format(episode, np.sum(rewards), steps, average_lengths[-1]))
                break
        
        # compute Q values
        Qvals = np.zeros_like(values)
        for t in reversed(range(len(rewards))):
            Qval = rewards[t] + GAMMA * Qval
            Qvals[t] = Qval
  
        #update actor critic
        values = torch.FloatTensor(values)
        Qvals = torch.FloatTensor(Qvals)
        log_probs = torch.stack(log_probs)
        
        advantage = Qvals - values
        actor_loss = (-log_probs * advantage).mean()
        critic_loss = 0.5 * advantage.pow(2).mean()
        ac_loss = actor_loss + critic_loss + 0.001 * entropy_term
        
        ac_optimizer.zero_grad()
        ac_loss.backward()
        ac_optimizer.step()
        
        #====================================================================================================
        #to see the change of the weights====================================================================
        #====================================================================================================
        print("=======================================")
        print("actor_critic.actor_fc1.weight : {}".format(actor_critic.actor_linear1.weight))
        print("actor_critic.critic_fc2.weight : {}".format(actor_critic.critic_linear1.weight))
        #====================================================================================================
    
    # Plot results
    smoothed_rewards = pd.Series.rolling(pd.Series(all_rewards), 10).mean()
    smoothed_rewards = [elem for elem in smoothed_rewards]
    plt.plot(all_rewards)
    plt.plot(smoothend_rewards)
    plt.plot()
    plt.xlabel('Episode')
    plt.ylabel('Reward')
    plt.show()

    plt.plot(all_lengths)
    plt.plot(average_lengths)
    plt.xlabel('Episode')
    plt.ylabel('Episode length')
    plt.show()

# %%
if __name__ == "__main__":
    env = gym.make("CartPole-v0")
    a2c(env)
# Out:
# episode: 0, reward: 16.0, total length: 15, average length: 15.0
# =======================================
# actor_critic.actor_fc1.weight : Parameter containing:
# tensor([[-0.2298,  0.2770, -0.1036, -0.3950],
#         [ 0.4676, -0.4538, -0.2897, -0.1354],
#         [ 0.1991,  0.3025, -0.1911,  0.2680],
#         ...,
#         [ 0.4285, -0.3660, -0.0486, -0.3200],
#         [-0.1304, -0.1343,  0.2468,  0.0368],
#         [-0.0309,  0.3450,  0.1751,  0.4247]], requires_grad=True)
# actor_critic.critic_fc2.weight : Parameter containing:
# tensor([[-0.4247, -0.4649, -0.4878,  0.2030],
#         [-0.1702,  0.2981, -0.3766,  0.1905],
#         [-0.0766, -0.3158, -0.3515, -0.2254],
#         ...,
#         [-0.0020,  0.3974,  0.0123, -0.3448],
#         [ 0.0831,  0.0301,  0.2025, -0.3015],
#         [-0.0452, -0.2938, -0.1895, -0.4559]], requires_grad=True)
# =======================================
# actor_critic.actor_fc1.weight : Parameter containing:
# tensor([[-0.2301,  0.2770, -0.1034, -0.3950],
#         [ 0.4679, -0.4539, -0.2900, -0.1353],
#         [ 0.1988,  0.3024, -0.1908,  0.2680],
#         ...,
#         [ 0.4283, -0.3662, -0.0484, -0.3198],
#         [-0.1304, -0.1343,  0.2468,  0.0368],
#         [-0.0311,  0.3449,  0.1753,  0.4248]], requires_grad=True)
# actor_critic.critic_fc2.weight : Parameter containing:
# tensor([[-0.4247, -0.4649, -0.4878,  0.2030],
#         [-0.1702,  0.2981, -0.3766,  0.1905],
#         [-0.0766, -0.3158, -0.3515, -0.2254],
#         ...,
#         [-0.0020,  0.3974,  0.0123, -0.3448],
#         [ 0.0831,  0.0301,  0.2025, -0.3015],
#         [-0.0452, -0.2938, -0.1895, -0.4559]], requires_grad=True)
# =======================================
# actor_critic.actor_fc1.weight : Parameter containing:
# tensor([[-0.2304,  0.2771, -0.1032, -0.3951],
#         [ 0.4682, -0.4539, -0.2901, -0.1353],
#         [ 0.1985,  0.3024, -0.1906,  0.2680],
#         ...,
#         [ 0.4281, -0.3664, -0.0481, -0.3196],
#         [-0.1304, -0.1343,  0.2468,  0.0368],
#         [-0.0314,  0.3449,  0.1754,  0.4247]], requires_grad=True)
# actor_critic.critic_fc2.weight : Parameter containing:
# tensor([[-0.4247, -0.4649, -0.4878,  0.2030],
#         [-0.1702,  0.2981, -0.3766,  0.1905],
#         [-0.0766, -0.3158, -0.3515, -0.2254],
#         ...,
#         [-0.0020,  0.3974,  0.0123, -0.3448],
#         [ 0.0831,  0.0301,  0.2025, -0.3015],
#         [-0.0452, -0.2938, -0.1895, -0.4559]], requires_grad=True)
# =======================================
# actor_critic.actor_fc1.weight : Parameter containing:
# tensor([[-0.2305,  0.2772, -0.1032, -0.3952],
#         [ 0.4683, -0.4540, -0.2901, -0.1352],
#         [ 0.1984,  0.3025, -0.1907,  0.2679],
#         ...,
#         [ 0.4281, -0.3665, -0.0481, -0.3195],
#         [-0.1304, -0.1343,  0.2468,  0.0368],
#         [-0.0315,  0.3451,  0.1753,  0.4245]], requires_grad=True)
# actor_critic.critic_fc2.weight : Parameter containing:
# tensor([[-0.4247, -0.4649, -0.4878,  0.2030],
#         [-0.1702,  0.2981, -0.3766,  0.1905],
#         [-0.0766, -0.3158, -0.3515, -0.2254],
#         ...,
#         [-0.0020,  0.3974,  0.0123, -0.3448],
#         [ 0.0831,  0.0301,  0.2025, -0.3015],
#         [-0.0452, -0.2938, -0.1895, -0.4559]], requires_grad=True)
# =======================================
# actor_critic.actor_fc1.weight : Parameter containing:
# tensor([[-0.2306,  0.2772, -0.1032, -0.3952],
#         [ 0.4684, -0.4540, -0.2901, -0.1351],
#         [ 0.1983,  0.3025, -0.1907,  0.2679],
#         ...,
#         [ 0.4280, -0.3665, -0.0480, -0.3195],
#         [-0.1304, -0.1343,  0.2468,  0.0368],
#         [-0.0315,  0.3452,  0.1753,  0.4244]], requires_grad=True)
# actor_critic.critic_fc2.weight : Parameter containing:
# tensor([[-0.4247, -0.4649, -0.4878,  0.2030],
#         [-0.1702,  0.2981, -0.3766,  0.1905],
#         [-0.0766, -0.3158, -0.3515, -0.2254],
#         ...,
#         [-0.0020,  0.3974,  0.0123, -0.3448],
#         [ 0.0831,  0.0301,  0.2025, -0.3015],
#         [-0.0452, -0.2938, -0.1895, -0.4559]], requires_grad=True)
# =======================================
# actor_critic.actor_fc1.weight : Parameter containing:
# tensor([[-0.2308,  0.2771, -0.1030, -0.3952],
#         [ 0.4686, -0.4540, -0.2902, -0.1352],
#         [ 0.1982,  0.3023, -0.1905,  0.2681],
#         ...,
#         [ 0.4280, -0.3666, -0.0480, -0.3194],
#         [-0.1304, -0.1343,  0.2468,  0.0368],
#         [-0.0317,  0.3451,  0.1754,  0.4245]], requires_grad=True)
# actor_critic.critic_fc2.weight : Parameter containing:
# tensor([[-0.4247, -0.4649, -0.4878,  0.2030],
#         [-0.1702,  0.2981, -0.3766,  0.1905],
#         [-0.0766, -0.3158, -0.3515, -0.2254],
#         ...,
#         [-0.0020,  0.3974,  0.0123, -0.3448],
#         [ 0.0831,  0.0301,  0.2025, -0.3015],
#         [-0.0452, -0.2938, -0.1895, -0.4559]], requires_grad=True)
# =======================================
# actor_critic.actor_fc1.weight : Parameter containing:
# tensor([[-0.2309,  0.2771, -0.1030, -0.3952],
#         [ 0.4687, -0.4540, -0.2903, -0.1352],
#         [ 0.1982,  0.3023, -0.1905,  0.2681],
#         ...,
#         [ 0.4278, -0.3668, -0.0478, -0.3192],
#         [-0.1304, -0.1343,  0.2468,  0.0368],
#         [-0.0316,  0.3451,  0.1754,  0.4244]], requires_grad=True)
# actor_critic.critic_fc2.weight : Parameter containing:
# tensor([[-0.4247, -0.4649, -0.4878,  0.2030],
#         [-0.1702,  0.2981, -0.3766,  0.1905],
#         [-0.0766, -0.3158, -0.3515, -0.2254],
#         ...,
#         [-0.0020,  0.3974,  0.0123, -0.3448],
#         [ 0.0831,  0.0301,  0.2025, -0.3015],
#         [-0.0452, -0.2938, -0.1895, -0.4559]], requires_grad=True)
# =======================================
# actor_critic.actor_fc1.weight : Parameter containing:
# tensor([[-0.2309,  0.2771, -0.1030, -0.3951],
#         [ 0.4687, -0.4540, -0.2903, -0.1352],
#         [ 0.1982,  0.3022, -0.1905,  0.2682],
#         ...,
#         [ 0.4277, -0.3669, -0.0477, -0.3191],
#         [-0.1304, -0.1343,  0.2468,  0.0368],
#         [-0.0316,  0.3451,  0.1754,  0.4245]], requires_grad=True)
# actor_critic.critic_fc2.weight : Parameter containing:
# tensor([[-0.4247, -0.4649, -0.4878,  0.2030],
#         [-0.1702,  0.2981, -0.3766,  0.1905],
#         [-0.0766, -0.3158, -0.3515, -0.2254],
#         ...,
#         [-0.0020,  0.3974,  0.0123, -0.3448],
#         [ 0.0831,  0.0301,  0.2025, -0.3015],
#         [-0.0452, -0.2938, -0.1895, -0.4559]], requires_grad=True)
# =======================================
# actor_critic.actor_fc1.weight : Parameter containing:
# tensor([[-0.2309,  0.2770, -0.1029, -0.3950],
#         [ 0.4688, -0.4539, -0.2904, -0.1352],
#         [ 0.1982,  0.3020, -0.1905,  0.2683],
#         ...,
#         [ 0.4276, -0.3671, -0.0476, -0.3189],
#         [-0.1304, -0.1343,  0.2468,  0.0368],
#         [-0.0315,  0.3450,  0.1754,  0.4246]], requires_grad=True)
# actor_critic.critic_fc2.weight : Parameter containing:
# tensor([[-0.4247, -0.4649, -0.4878,  0.2030],
#         [-0.1702,  0.2981, -0.3766,  0.1905],
#         [-0.0766, -0.3158, -0.3515, -0.2254],
#         ...,
#         [-0.0020,  0.3974,  0.0123, -0.3448],
#         [ 0.0831,  0.0301,  0.2025, -0.3015],
#         [-0.0452, -0.2938, -0.1895, -0.4559]], requires_grad=True)
# =======================================
# actor_critic.actor_fc1.weight : Parameter containing:
# tensor([[-0.2308,  0.2769, -0.1029, -0.3949],
#         [ 0.4688, -0.4539, -0.2904, -0.1352],
#         [ 0.1983,  0.3019, -0.1905,  0.2685],
#         ...,
#         [ 0.4274, -0.3672, -0.0474, -0.3188],
#         [-0.1304, -0.1343,  0.2468,  0.0368],
#         [-0.0315,  0.3449,  0.1754,  0.4247]], requires_grad=True)
# actor_critic.critic_fc2.weight : Parameter containing:
# tensor([[-0.4247, -0.4649, -0.4878,  0.2030],
#         [-0.1702,  0.2981, -0.3766,  0.1905],
#         [-0.0766, -0.3158, -0.3515, -0.2254],
#         ...,
#         [-0.0020,  0.3974,  0.0123, -0.3448],
#         [ 0.0831,  0.0301,  0.2025, -0.3015],
#         [-0.0452, -0.2938, -0.1895, -0.4559]], requires_grad=True)
# episode: 10, reward: 16.0, total length: 15, average length: 17.1
# =======================================
# actor_critic.actor_fc1.weight : Parameter containing:
# tensor([[-0.2308,  0.2768, -0.1029, -0.3948],
#         [ 0.4689, -0.4539, -0.2904, -0.1353],
#         [ 0.1984,  0.3018, -0.1904,  0.2687],
#         ...,
#         [ 0.4273, -0.3674, -0.0473, -0.3186],
#         [-0.1304, -0.1343,  0.2468,  0.0368],
#         [-0.0313,  0.3449,  0.1754,  0.4248]], requires_grad=True)
# actor_critic.critic_fc2.weight : Parameter containing:
# tensor([[-0.4247, -0.4649, -0.4878,  0.2030],
#         [-0.1702,  0.2981, -0.3766,  0.1905],
#         [-0.0766, -0.3158, -0.3515, -0.2254],
#         ...,
#         [-0.0020,  0.3974,  0.0123, -0.3448],
#         [ 0.0831,  0.0301,  0.2025, -0.3015],
#         [-0.0452, -0.2938, -0.1895, -0.4559]], requires_grad=True)
# =======================================
# actor_critic.actor_fc1.weight : Parameter containing:
# tensor([[-0.2307,  0.2767, -0.1028, -0.3947],
#         [ 0.4689, -0.4538, -0.2905, -0.1353],
#         [ 0.1985,  0.3016, -0.1904,  0.2688],
#         ...,
#         [ 0.4272, -0.3674, -0.0472, -0.3186],
#         [-0.1304, -0.1343,  0.2468,  0.0368],
#         [-0.0312,  0.3448,  0.1754,  0.4248]], requires_grad=True)
# actor_critic.critic_fc2.weight : Parameter containing:
# tensor([[-0.4247, -0.4649, -0.4878,  0.2030],
#         [-0.1702,  0.2981, -0.3766,  0.1905],
#         [-0.0766, -0.3158, -0.3515, -0.2254],
#         ...,
#         [-0.0020,  0.3974,  0.0123, -0.3448],
#         [ 0.0831,  0.0301,  0.2025, -0.3015],
#         [-0.0452, -0.2938, -0.1895, -0.4559]], requires_grad=True)
# =======================================
# actor_critic.actor_fc1.weight : Parameter containing:
# tensor([[-0.2306,  0.2767, -0.1029, -0.3947],
#         [ 0.4690, -0.4538, -0.2905, -0.1353],
#         [ 0.1987,  0.3016, -0.1905,  0.2688],
#         ...,
#         [ 0.4272, -0.3675, -0.0472, -0.3186],
#         [-0.1304, -0.1343,  0.2468,  0.0368],
#         [-0.0311,  0.3448,  0.1753,  0.4248]], requires_grad=True)
# actor_critic.critic_fc2.weight : Parameter containing:
# tensor([[-0.4247, -0.4649, -0.4878,  0.2030],
#         [-0.1702,  0.2981, -0.3766,  0.1905],
#         [-0.0766, -0.3158, -0.3515, -0.2254],
#         ...,
#         [-0.0020,  0.3974,  0.0123, -0.3448],
#         [ 0.0831,  0.0301,  0.2025, -0.3015],
#         [-0.0452, -0.2938, -0.1895, -0.4559]], requires_grad=True)
# =======================================
# actor_critic.actor_fc1.weight : Parameter containing:
# tensor([[-0.2304,  0.2767, -0.1029, -0.3947],
#         [ 0.4691, -0.4537, -0.2906, -0.1354],
#         [ 0.1989,  0.3016, -0.1906,  0.2688],
#         ...,
#         [ 0.4271, -0.3675, -0.0472, -0.3185],
#         [-0.1304, -0.1343,  0.2468,  0.0368],
#         [-0.0309,  0.3448,  0.1753,  0.4249]], requires_grad=True)
# actor_critic.critic_fc2.weight : Parameter containing:
# tensor([[-0.4247, -0.4649, -0.4878,  0.2030],
#         [-0.1702,  0.2981, -0.3766,  0.1905],
#         [-0.0766, -0.3158, -0.3515, -0.2254],
#         ...,
#         [-0.0020,  0.3974,  0.0123, -0.3448],
#         [ 0.0831,  0.0301,  0.2025, -0.3015],
#         [-0.0452, -0.2938, -0.1895, -0.4559]], requires_grad=True)
# =======================================
# actor_critic.actor_fc1.weight : Parameter containing:
# tensor([[-0.2303,  0.2767, -0.1030, -0.3947],
#         [ 0.4693, -0.4536, -0.2907, -0.1355],
#         [ 0.1991,  0.3016, -0.1907,  0.2688],
#         ...,
#         [ 0.4271, -0.3675, -0.0471, -0.3185],
#         [-0.1304, -0.1343,  0.2468,  0.0368],
#         [-0.0307,  0.3448,  0.1752,  0.4248]], requires_grad=True)
# actor_critic.critic_fc2.weight : Parameter containing:
# tensor([[-0.4247, -0.4649, -0.4878,  0.2030],
#         [-0.1702,  0.2981, -0.3766,  0.1905],
#         [-0.0766, -0.3158, -0.3515, -0.2254],
#         ...,
#         [-0.0020,  0.3974,  0.0123, -0.3448],
#         [ 0.0831,  0.0301,  0.2025, -0.3015],
#         [-0.0452, -0.2938, -0.1895, -0.4559]], requires_grad=True)
# =======================================
# actor_critic.actor_fc1.weight : Parameter containing:
# tensor([[-0.2301,  0.2768, -0.1030, -0.3948],
#         [ 0.4694, -0.4535, -0.2908, -0.1356],
#         [ 0.1993,  0.3018, -0.1908,  0.2687],
#         ...,
#         [ 0.4270, -0.3676, -0.0470, -0.3184],
#         [-0.1304, -0.1343,  0.2468,  0.0368],
#         [-0.0305,  0.3449,  0.1751,  0.4247]], requires_grad=True)
# actor_critic.critic_fc2.weight : Parameter containing:
# tensor([[-0.4247, -0.4649, -0.4878,  0.2030],
#         [-0.1702,  0.2981, -0.3766,  0.1905],
#         [-0.0766, -0.3158, -0.3515, -0.2254],
#         ...,
#         [-0.0020,  0.3974,  0.0123, -0.3448],
#         [ 0.0831,  0.0301,  0.2025, -0.3015],
#         [-0.0452, -0.2938, -0.1895, -0.4559]], requires_grad=True)
# =======================================
# actor_critic.actor_fc1.weight : Parameter containing:
# tensor([[-0.2301,  0.2768, -0.1030, -0.3948],
#         [ 0.4695, -0.4534, -0.2908, -0.1357],
#         [ 0.1994,  0.3019, -0.1909,  0.2686],
#         ...,
#         [ 0.4269, -0.3677, -0.0470, -0.3183],
#         [-0.1304, -0.1343,  0.2468,  0.0368],
#         [-0.0304,  0.3451,  0.1750,  0.4246]], requires_grad=True)
# actor_critic.critic_fc2.weight : Parameter containing:
# tensor([[-0.4247, -0.4649, -0.4878,  0.2030],
#         [-0.1702,  0.2981, -0.3766,  0.1905],
#         [-0.0766, -0.3158, -0.3515, -0.2254],
#         ...,
#         [-0.0020,  0.3974,  0.0123, -0.3448],
#         [ 0.0831,  0.0301,  0.2025, -0.3015],
#         [-0.0452, -0.2938, -0.1895, -0.4559]], requires_grad=True)
# =======================================
# actor_critic.actor_fc1.weight : Parameter containing:
# tensor([[-0.2300,  0.2768, -0.1030, -0.3948],
#         [ 0.4695, -0.4533, -0.2908, -0.1358],
#         [ 0.1995,  0.3018, -0.1908,  0.2686],
#         ...,
#         [ 0.4269, -0.3678, -0.0469, -0.3183],
#         [-0.1304, -0.1343,  0.2468,  0.0368],
#         [-0.0304,  0.3451,  0.1750,  0.4246]], requires_grad=True)
# actor_critic.critic_fc2.weight : Parameter containing:
# tensor([[-0.4247, -0.4649, -0.4878,  0.2030],
#         [-0.1702,  0.2981, -0.3766,  0.1905],
#         [-0.0766, -0.3158, -0.3515, -0.2254],
#         ...,
#         [-0.0020,  0.3974,  0.0123, -0.3448],
#         [ 0.0831,  0.0301,  0.2025, -0.3015],
#         [-0.0452, -0.2938, -0.1895, -0.4559]], requires_grad=True)
# =======================================
# actor_critic.actor_fc1.weight : Parameter containing:
# tensor([[-0.2299,  0.2768, -0.1030, -0.3948],
#         [ 0.4695, -0.4532, -0.2908, -0.1359],
#         [ 0.1995,  0.3018, -0.1908,  0.2686],
#         ...,
#         [ 0.4268, -0.3679, -0.0468, -0.3182],
#         [-0.1304, -0.1343,  0.2468,  0.0368],
#         [-0.0303,  0.3451,  0.1750,  0.4245]], requires_grad=True)
# actor_critic.critic_fc2.weight : Parameter containing:
# tensor([[-0.4247, -0.4649, -0.4878,  0.2030],
#         [-0.1702,  0.2981, -0.3766,  0.1905],
#         [-0.0766, -0.3158, -0.3515, -0.2254],
#         ...,
#         [-0.0020,  0.3974,  0.0123, -0.3448],
#         [ 0.0831,  0.0301,  0.2025, -0.3015],
#         [-0.0452, -0.2938, -0.1895, -0.4559]], requires_grad=True)
# =======================================
# actor_critic.actor_fc1.weight : Parameter containing:
# tensor([[-0.2299,  0.2768, -0.1030, -0.3948],
#         [ 0.4696, -0.4531, -0.2908, -0.1360],
#         [ 0.1995,  0.3018, -0.1908,  0.2686],
#         ...,
#         [ 0.4267, -0.3679, -0.0468, -0.3181],
#         [-0.1304, -0.1343,  0.2468,  0.0368],
#         [-0.0303,  0.3451,  0.1750,  0.4245]], requires_grad=True)
# actor_critic.critic_fc2.weight : Parameter containing:
# tensor([[-0.4247, -0.4649, -0.4878,  0.2030],
#         [-0.1702,  0.2981, -0.3766,  0.1905],
#         [-0.0766, -0.3158, -0.3515, -0.2254],
#         ...,
#         [-0.0020,  0.3974,  0.0123, -0.3448],
#         [ 0.0831,  0.0301,  0.2025, -0.3015],
#         [-0.0452, -0.2938, -0.1895, -0.4559]], requires_grad=True)
# episode: 20, reward: 66.0, total length: 65, average length: 22.5
# =======================================
# actor_critic.actor_fc1.weight : Parameter containing:
# tensor([[-0.2300,  0.2766, -0.1028, -0.3946],
#         [ 0.4694, -0.4532, -0.2907, -0.1359],
#         [ 0.1994,  0.3016, -0.1906,  0.2688],
#         ...,
#         [ 0.4267, -0.3680, -0.0467, -0.3180],
#         [-0.1304, -0.1343,  0.2468,  0.0368],
#         [-0.0303,  0.3450,  0.1751,  0.4246]], requires_grad=True)
# actor_critic.critic_fc2.weight : Parameter containing:
# tensor([[-0.4247, -0.4649, -0.4878,  0.2030],
#         [-0.1702,  0.2981, -0.3766,  0.1905],
#         [-0.0766, -0.3158, -0.3515, -0.2254],
#         ...,
#         [-0.0020,  0.3974,  0.0123, -0.3448],
#         [ 0.0831,  0.0301,  0.2025, -0.3015],
#         [-0.0452, -0.2938, -0.1895, -0.4559]], requires_grad=True)
# =======================================
# actor_critic.actor_fc1.weight : Parameter containing:
# tensor([[-0.2301,  0.2765, -0.1027, -0.3945],
#         [ 0.4694, -0.4532, -0.2905, -0.1358],
#         [ 0.1994,  0.3015, -0.1905,  0.2689],
#         ...,
#         [ 0.4266, -0.3681, -0.0467, -0.3180],
#         [-0.1304, -0.1343,  0.2468,  0.0368],
#         [-0.0304,  0.3449,  0.1752,  0.4247]], requires_grad=True)
# actor_critic.critic_fc2.weight : Parameter containing:
# tensor([[-0.4247, -0.4649, -0.4878,  0.2030],
#         [-0.1702,  0.2981, -0.3766,  0.1905],
#         [-0.0766, -0.3158, -0.3515, -0.2254],
#         ...,
#         [-0.0020,  0.3974,  0.0123, -0.3448],
#         [ 0.0831,  0.0301,  0.2025, -0.3015],
#         [-0.0452, -0.2938, -0.1895, -0.4559]], requires_grad=True)
# =======================================
# actor_critic.actor_fc1.weight : Parameter containing:
# tensor([[-0.2301,  0.2764, -0.1026, -0.3944],
#         [ 0.4693, -0.4533, -0.2904, -0.1358],
#         [ 0.1993,  0.3014, -0.1904,  0.2690],
#         ...,
#         [ 0.4266, -0.3681, -0.0466, -0.3179],
#         [-0.1304, -0.1343,  0.2468,  0.0368],
#         [-0.0304,  0.3448,  0.1753,  0.4248]], requires_grad=True)
# actor_critic.critic_fc2.weight : Parameter containing:
# tensor([[-0.4247, -0.4649, -0.4878,  0.2030],
#         [-0.1702,  0.2981, -0.3766,  0.1905],
#         [-0.0766, -0.3158, -0.3515, -0.2254],
#         ...,
#         [-0.0020,  0.3974,  0.0123, -0.3448],
#         [ 0.0831,  0.0301,  0.2025, -0.3015],
#         [-0.0452, -0.2938, -0.1895, -0.4559]], requires_grad=True)
# =======================================
# actor_critic.actor_fc1.weight : Parameter containing:
# tensor([[-0.2302,  0.2762, -0.1026, -0.3942],
#         [ 0.4692, -0.4534, -0.2903, -0.1357],
#         [ 0.1993,  0.3012, -0.1903,  0.2692],
#         ...,
#         [ 0.4265, -0.3682, -0.0466, -0.3179],
#         [-0.1304, -0.1343,  0.2468,  0.0368],
#         [-0.0305,  0.3447,  0.1754,  0.4250]], requires_grad=True)
# actor_critic.critic_fc2.weight : Parameter containing:
# tensor([[-0.4247, -0.4649, -0.4878,  0.2030],
#         [-0.1702,  0.2981, -0.3766,  0.1905],
#         [-0.0766, -0.3158, -0.3515, -0.2254],
#         ...,
#         [-0.0020,  0.3974,  0.0123, -0.3448],
#         [ 0.0831,  0.0301,  0.2025, -0.3015],
#         [-0.0452, -0.2938, -0.1895, -0.4559]], requires_grad=True)
# =======================================
# actor_critic.actor_fc1.weight : Parameter containing:
# tensor([[-0.2302,  0.2761, -0.1025, -0.3942],
#         [ 0.4691, -0.4534, -0.2902, -0.1356],
#         [ 0.1992,  0.3011, -0.1902,  0.2693],
#         ...,
#         [ 0.4264, -0.3683, -0.0465, -0.3178],
#         [-0.1304, -0.1343,  0.2468,  0.0368],
#         [-0.0306,  0.3446,  0.1755,  0.4250]], requires_grad=True)
# actor_critic.critic_fc2.weight : Parameter containing:
# tensor([[-0.4247, -0.4649, -0.4878,  0.2030],
#         [-0.1702,  0.2981, -0.3766,  0.1905],
#         [-0.0766, -0.3158, -0.3515, -0.2254],
#         ...,
#         [-0.0020,  0.3974,  0.0123, -0.3448],
#         [ 0.0831,  0.0301,  0.2025, -0.3015],
#         [-0.0452, -0.2938, -0.1895, -0.4559]], requires_grad=True)
# =======================================
# actor_critic.actor_fc1.weight : Parameter containing:
# tensor([[-0.2304,  0.2760, -0.1023, -0.3940],
#         [ 0.4690, -0.4535, -0.2900, -0.1355],
#         [ 0.1991,  0.3010, -0.1901,  0.2694],
#         ...,
#         [ 0.4263, -0.3684, -0.0464, -0.3177],
#         [-0.1304, -0.1343,  0.2468,  0.0368],
#         [-0.0307,  0.3445,  0.1756,  0.4251]], requires_grad=True)
# actor_critic.critic_fc2.weight : Parameter containing:
# tensor([[-0.4247, -0.4649, -0.4878,  0.2030],
#         [-0.1702,  0.2981, -0.3766,  0.1905],
#         [-0.0766, -0.3158, -0.3515, -0.2254],
#         ...,
#         [-0.0020,  0.3974,  0.0123, -0.3448],
#         [ 0.0831,  0.0301,  0.2025, -0.3015],
#         [-0.0452, -0.2938, -0.1895, -0.4559]], requires_grad=True)
# =======================================
# actor_critic.actor_fc1.weight : Parameter containing:
# tensor([[-0.2305,  0.2759, -0.1022, -0.3939],
#         [ 0.4688, -0.4536, -0.2898, -0.1354],
#         [ 0.1990,  0.3009, -0.1899,  0.2695],
#         ...,
#         [ 0.4262, -0.3685, -0.0462, -0.3175],
#         [-0.1304, -0.1343,  0.2468,  0.0368],
#         [-0.0308,  0.3444,  0.1758,  0.4252]], requires_grad=True)
# actor_critic.critic_fc2.weight : Parameter containing:
# tensor([[-0.4247, -0.4649, -0.4878,  0.2030],
#         [-0.1702,  0.2981, -0.3766,  0.1905],
#         [-0.0766, -0.3158, -0.3515, -0.2254],
#         ...,
#         [-0.0020,  0.3974,  0.0123, -0.3448],
#         [ 0.0831,  0.0301,  0.2025, -0.3015],
#         [-0.0452, -0.2938, -0.1895, -0.4559]], requires_grad=True)
# =======================================
# actor_critic.actor_fc1.weight : Parameter containing:
# tensor([[-0.2306,  0.2758, -0.1021, -0.3938],
#         [ 0.4687, -0.4537, -0.2896, -0.1353],
#         [ 0.1989,  0.3008, -0.1898,  0.2697],
#         ...,
#         [ 0.4261, -0.3686, -0.0461, -0.3174],
#         [-0.1304, -0.1343,  0.2468,  0.0368],
#         [-0.0309,  0.3443,  0.1759,  0.4253]], requires_grad=True)
# actor_critic.critic_fc2.weight : Parameter containing:
# tensor([[-0.4247, -0.4649, -0.4878,  0.2030],
#         [-0.1702,  0.2981, -0.3766,  0.1905],
#         [-0.0766, -0.3158, -0.3515, -0.2254],
#         ...,
#         [-0.0020,  0.3974,  0.0123, -0.3448],
#         [ 0.0831,  0.0301,  0.2025, -0.3015],
#         [-0.0452, -0.2938, -0.1895, -0.4559]], requires_grad=True)
# =======================================
# actor_critic.actor_fc1.weight : Parameter containing:
# tensor([[-0.2306,  0.2757, -0.1020, -0.3937],
#         [ 0.4687, -0.4538, -0.2896, -0.1352],
#         [ 0.1989,  0.3007, -0.1897,  0.2697],
#         ...,
#         [ 0.4260, -0.3688, -0.0460, -0.3173],
#         [-0.1304, -0.1343,  0.2468,  0.0368],
#         [-0.0309,  0.3443,  0.1759,  0.4254]], requires_grad=True)
# actor_critic.critic_fc2.weight : Parameter containing:
# tensor([[-0.4247, -0.4649, -0.4878,  0.2030],
#         [-0.1702,  0.2981, -0.3766,  0.1905],
#         [-0.0766, -0.3158, -0.3515, -0.2254],
#         ...,
#         [-0.0020,  0.3974,  0.0123, -0.3448],
#         [ 0.0831,  0.0301,  0.2025, -0.3015],
#         [-0.0452, -0.2938, -0.1895, -0.4559]], requires_grad=True)
# =======================================
# actor_critic.actor_fc1.weight : Parameter containing:
# tensor([[-0.2307,  0.2756, -0.1019, -0.3936],
#         [ 0.4687, -0.4538, -0.2895, -0.1352],
#         [ 0.1988,  0.3006, -0.1897,  0.2698],
#         ...,
#         [ 0.4260, -0.3688, -0.0459, -0.3172],
#         [-0.1304, -0.1343,  0.2468,  0.0368],
#         [-0.0309,  0.3442,  0.1759,  0.4254]], requires_grad=True)
# actor_critic.critic_fc2.weight : Parameter containing:
# tensor([[-0.4247, -0.4649, -0.4878,  0.2030],
#         [-0.1702,  0.2981, -0.3766,  0.1905],
#         [-0.0766, -0.3158, -0.3515, -0.2254],
#         ...,
#         [-0.0020,  0.3974,  0.0123, -0.3448],
#         [ 0.0831,  0.0301,  0.2025, -0.3015],
#         [-0.0452, -0.2938, -0.1895, -0.4559]], requires_grad=True)
# episode: 30, reward: 25.0, total length: 24, average length: 22.7
# =======================================
# actor_critic.actor_fc1.weight : Parameter containing:
# tensor([[-0.2307,  0.2755, -0.1018, -0.3935],
#         [ 0.4687, -0.4538, -0.2895, -0.1352],
#         [ 0.1988,  0.3006, -0.1896,  0.2699],
#         ...,
#         [ 0.4259, -0.3689, -0.0459, -0.3171],
#         [-0.1304, -0.1343,  0.2468,  0.0368],
#         [-0.0309,  0.3441,  0.1759,  0.4255]], requires_grad=True)
# actor_critic.critic_fc2.weight : Parameter containing:
# tensor([[-0.4247, -0.4649, -0.4878,  0.2030],
#         [-0.1702,  0.2981, -0.3766,  0.1905],
#         [-0.0766, -0.3158, -0.3515, -0.2254],
#         ...,
#         [-0.0020,  0.3974,  0.0123, -0.3448],
#         [ 0.0831,  0.0301,  0.2025, -0.3015],
#         [-0.0452, -0.2938, -0.1895, -0.4559]], requires_grad=True)
# =======================================
# actor_critic.actor_fc1.weight : Parameter containing:
# tensor([[-0.2308,  0.2754, -0.1018, -0.3934],
#         [ 0.4687, -0.4539, -0.2894, -0.1351],
#         [ 0.1988,  0.3005, -0.1896,  0.2699],
#         ...,
#         [ 0.4258, -0.3690, -0.0458, -0.3170],
#         [-0.1304, -0.1343,  0.2468,  0.0368],
#         [-0.0309,  0.3441,  0.1760,  0.4255]], requires_grad=True)
# actor_critic.critic_fc2.weight : Parameter containing:
# tensor([[-0.4247, -0.4649, -0.4878,  0.2030],
#         [-0.1702,  0.2981, -0.3766,  0.1905],
#         [-0.0766, -0.3158, -0.3515, -0.2254],
#         ...,
#         [-0.0020,  0.3974,  0.0123, -0.3448],
#         [ 0.0831,  0.0301,  0.2025, -0.3015],
#         [-0.0452, -0.2938, -0.1895, -0.4559]], requires_grad=True)
# =======================================
# actor_critic.actor_fc1.weight : Parameter containing:
# tensor([[-0.2308,  0.2754, -0.1017, -0.3934],
#         [ 0.4687, -0.4539, -0.2893, -0.1350],
#         [ 0.1988,  0.3005, -0.1895,  0.2700],
#         ...,
#         [ 0.4258, -0.3691, -0.0457, -0.3170],
#         [-0.1304, -0.1343,  0.2468,  0.0368],
#         [-0.0310,  0.3440,  0.1760,  0.4256]], requires_grad=True)
# actor_critic.critic_fc2.weight : Parameter containing:
# tensor([[-0.4247, -0.4649, -0.4878,  0.2030],
#         [-0.1702,  0.2981, -0.3766,  0.1905],
#         [-0.0766, -0.3158, -0.3515, -0.2254],
#         ...,
#         [-0.0020,  0.3974,  0.0123, -0.3448],
#         [ 0.0831,  0.0301,  0.2025, -0.3015],
#         [-0.0452, -0.2938, -0.1895, -0.4559]], requires_grad=True)
# =======================================
# actor_critic.actor_fc1.weight : Parameter containing:
# tensor([[-0.2309,  0.2753, -0.1016, -0.3932],
#         [ 0.4686, -0.4540, -0.2892, -0.1350],
#         [ 0.1987,  0.3004, -0.1895,  0.2701],
#         ...,
#         [ 0.4257, -0.3692, -0.0457, -0.3169],
#         [-0.1304, -0.1343,  0.2468,  0.0368],
#         [-0.0310,  0.3439,  0.1761,  0.4257]], requires_grad=True)
# actor_critic.critic_fc2.weight : Parameter containing:
# tensor([[-0.4247, -0.4649, -0.4878,  0.2030],
#         [-0.1702,  0.2981, -0.3766,  0.1905],
#         [-0.0766, -0.3158, -0.3515, -0.2254],
#         ...,
#         [-0.0020,  0.3974,  0.0123, -0.3448],
#         [ 0.0831,  0.0301,  0.2025, -0.3015],
#         [-0.0452, -0.2938, -0.1895, -0.4559]], requires_grad=True)
# =======================================
# actor_critic.actor_fc1.weight : Parameter containing:
# tensor([[-0.2310,  0.2752, -0.1015, -0.3931],
#         [ 0.4686, -0.4540, -0.2892, -0.1349],
#         [ 0.1987,  0.3003, -0.1895,  0.2701],
#         ...,
#         [ 0.4257, -0.3693, -0.0456, -0.3168],
#         [-0.1304, -0.1343,  0.2468,  0.0368],
#         [-0.0310,  0.3438,  0.1761,  0.4258]], requires_grad=True)
# actor_critic.critic_fc2.weight : Parameter containing:
# tensor([[-0.4247, -0.4649, -0.4878,  0.2030],
#         [-0.1702,  0.2981, -0.3766,  0.1905],
#         [-0.0766, -0.3158, -0.3515, -0.2254],
#         ...,
#         [-0.0020,  0.3974,  0.0123, -0.3448],
#         [ 0.0831,  0.0301,  0.2025, -0.3015],
#         [-0.0452, -0.2938, -0.1895, -0.4559]], requires_grad=True)
# =======================================
# actor_critic.actor_fc1.weight : Parameter containing:
# tensor([[-0.2310,  0.2750, -0.1015, -0.3930],
#         [ 0.4686, -0.4541, -0.2892, -0.1349],
#         [ 0.1987,  0.3002, -0.1895,  0.2702],
#         ...,
#         [ 0.4256, -0.3693, -0.0456, -0.3168],
#         [-0.1304, -0.1343,  0.2468,  0.0368],
#         [-0.0310,  0.3437,  0.1761,  0.4258]], requires_grad=True)
# actor_critic.critic_fc2.weight : Parameter containing:
# tensor([[-0.4247, -0.4649, -0.4878,  0.2030],
#         [-0.1702,  0.2981, -0.3766,  0.1905],
#         [-0.0766, -0.3158, -0.3515, -0.2254],
#         ...,
#         [-0.0020,  0.3974,  0.0123, -0.3448],
#         [ 0.0831,  0.0301,  0.2025, -0.3015],
#         [-0.0452, -0.2938, -0.1895, -0.4559]], requires_grad=True)
# =======================================
# actor_critic.actor_fc1.weight : Parameter containing:
# tensor([[-0.2311,  0.2749, -0.1014, -0.3929],
#         [ 0.4686, -0.4541, -0.2892, -0.1348],
#         [ 0.1987,  0.3001, -0.1894,  0.2703],
#         ...,
#         [ 0.4256, -0.3694, -0.0455, -0.3167],
#         [-0.1304, -0.1343,  0.2468,  0.0368],
#         [-0.0311,  0.3436,  0.1761,  0.4259]], requires_grad=True)
# actor_critic.critic_fc2.weight : Parameter containing:
# tensor([[-0.4247, -0.4649, -0.4878,  0.2030],
#         [-0.1702,  0.2981, -0.3766,  0.1905],
#         [-0.0766, -0.3158, -0.3515, -0.2254],
#         ...,
#         [-0.0020,  0.3974,  0.0123, -0.3448],
#         [ 0.0831,  0.0301,  0.2025, -0.3015],
#         [-0.0452, -0.2938, -0.1895, -0.4559]], requires_grad=True)
# =======================================
# actor_critic.actor_fc1.weight : Parameter containing:
# tensor([[-0.2311,  0.2748, -0.1014, -0.3928],
#         [ 0.4686, -0.4542, -0.2891, -0.1348],
#         [ 0.1986,  0.3000, -0.1894,  0.2704],
#         ...,
#         [ 0.4256, -0.3695, -0.0454, -0.3166],
#         [-0.1304, -0.1343,  0.2468,  0.0368],
#         [-0.0311,  0.3435,  0.1761,  0.4260]], requires_grad=True)
# actor_critic.critic_fc2.weight : Parameter containing:
# tensor([[-0.4247, -0.4649, -0.4878,  0.2030],
#         [-0.1702,  0.2981, -0.3766,  0.1905],
#         [-0.0766, -0.3158, -0.3515, -0.2254],
#         ...,
#         [-0.0020,  0.3974,  0.0123, -0.3448],
#         [ 0.0831,  0.0301,  0.2025, -0.3015],
#         [-0.0452, -0.2938, -0.1895, -0.4559]], requires_grad=True)
# =======================================
# actor_critic.actor_fc1.weight : Parameter containing:
# tensor([[-0.2312,  0.2747, -0.1013, -0.3926],
#         [ 0.4686, -0.4542, -0.2891, -0.1347],
#         [ 0.1986,  0.2999, -0.1894,  0.2705],
#         ...,
#         [ 0.4255, -0.3695, -0.0454, -0.3165],
#         [-0.1304, -0.1343,  0.2468,  0.0368],
#         [-0.0311,  0.3434,  0.1761,  0.4261]], requires_grad=True)
# actor_critic.critic_fc2.weight : Parameter containing:
# tensor([[-0.4247, -0.4649, -0.4878,  0.2030],
#         [-0.1702,  0.2981, -0.3766,  0.1905],
#         [-0.0766, -0.3158, -0.3515, -0.2254],
#         ...,
#         [-0.0020,  0.3974,  0.0123, -0.3448],
#         [ 0.0831,  0.0301,  0.2025, -0.3015],
#         [-0.0452, -0.2938, -0.1895, -0.4559]], requires_grad=True)
# =======================================
# actor_critic.actor_fc1.weight : Parameter containing:
# tensor([[-0.2312,  0.2745, -0.1012, -0.3925],
#         [ 0.4686, -0.4543, -0.2890, -0.1346],
#         [ 0.1986,  0.2998, -0.1893,  0.2706],
#         ...,
#         [ 0.4255, -0.3696, -0.0453, -0.3165],
#         [-0.1304, -0.1343,  0.2468,  0.0368],
#         [-0.0311,  0.3433,  0.1762,  0.4262]], requires_grad=True)
# actor_critic.critic_fc2.weight : Parameter containing:
# tensor([[-0.4247, -0.4649, -0.4878,  0.2030],
#         [-0.1702,  0.2981, -0.3766,  0.1905],
#         [-0.0766, -0.3158, -0.3515, -0.2254],
#         ...,
#         [-0.0020,  0.3974,  0.0123, -0.3448],
#         [ 0.0831,  0.0301,  0.2025, -0.3015],
#         [-0.0452, -0.2938, -0.1895, -0.4559]], requires_grad=True)
# episode: 40, reward: 18.0, total length: 17, average length: 23.6
# =======================================
# actor_critic.actor_fc1.weight : Parameter containing:
# tensor([[-0.2313,  0.2743, -0.1011, -0.3923],
#         [ 0.4686, -0.4543, -0.2890, -0.1346],
#         [ 0.1985,  0.2997, -0.1892,  0.2707],
#         ...,
#         [ 0.4254, -0.3697, -0.0452, -0.3164],
#         [-0.1304, -0.1343,  0.2468,  0.0368],
#         [-0.0312,  0.3432,  0.1763,  0.4263]], requires_grad=True)
# actor_critic.critic_fc2.weight : Parameter containing:
# tensor([[-0.4247, -0.4649, -0.4878,  0.2030],
#         [-0.1702,  0.2981, -0.3766,  0.1905],
#         [-0.0766, -0.3158, -0.3515, -0.2254],
#         ...,
#         [-0.0020,  0.3974,  0.0123, -0.3448],
#         [ 0.0831,  0.0301,  0.2025, -0.3015],
#         [-0.0452, -0.2938, -0.1895, -0.4559]], requires_grad=True)
# =======================================
# actor_critic.actor_fc1.weight : Parameter containing:
# tensor([[-0.2314,  0.2742, -0.1010, -0.3922],
#         [ 0.4686, -0.4544, -0.2889, -0.1345],
#         [ 0.1985,  0.2996, -0.1891,  0.2708],
#         ...,
#         [ 0.4254, -0.3697, -0.0452, -0.3164],
#         [-0.1304, -0.1343,  0.2468,  0.0368],
#         [-0.0312,  0.3431,  0.1764,  0.4264]], requires_grad=True)
# actor_critic.critic_fc2.weight : Parameter containing:
# tensor([[-0.4247, -0.4649, -0.4878,  0.2030],
#         [-0.1702,  0.2981, -0.3766,  0.1905],
#         [-0.0766, -0.3158, -0.3515, -0.2254],
#         ...,
#         [-0.0020,  0.3974,  0.0123, -0.3448],
#         [ 0.0831,  0.0301,  0.2025, -0.3015],
#         [-0.0452, -0.2938, -0.1895, -0.4559]], requires_grad=True)
# =======================================
# actor_critic.actor_fc1.weight : Parameter containing:
# tensor([[-0.2315,  0.2741, -0.1009, -0.3920],
#         [ 0.4686, -0.4544, -0.2889, -0.1345],
#         [ 0.1984,  0.2995, -0.1891,  0.2709],
#         ...,
#         [ 0.4254, -0.3698, -0.0452, -0.3163],
#         [-0.1304, -0.1343,  0.2468,  0.0368],
#         [-0.0312,  0.3430,  0.1764,  0.4265]], requires_grad=True)
# actor_critic.critic_fc2.weight : Parameter containing:
# tensor([[-0.4247, -0.4649, -0.4878,  0.2030],
#         [-0.1702,  0.2981, -0.3766,  0.1905],
#         [-0.0766, -0.3158, -0.3515, -0.2254],
#         ...,
#         [-0.0020,  0.3974,  0.0123, -0.3448],
#         [ 0.0831,  0.0301,  0.2025, -0.3015],
#         [-0.0452, -0.2938, -0.1895, -0.4559]], requires_grad=True)
# =======================================
# actor_critic.actor_fc1.weight : Parameter containing:
# tensor([[-0.2315,  0.2739, -0.1008, -0.3919],
#         [ 0.4685, -0.4545, -0.2888, -0.1344],
#         [ 0.1983,  0.2994, -0.1890,  0.2710],
#         ...,
#         [ 0.4254, -0.3698, -0.0451, -0.3163],
#         [-0.1304, -0.1343,  0.2468,  0.0368],
#         [-0.0313,  0.3430,  0.1764,  0.4265]], requires_grad=True)
# actor_critic.critic_fc2.weight : Parameter containing:
# tensor([[-0.4247, -0.4649, -0.4878,  0.2030],
#         [-0.1702,  0.2981, -0.3766,  0.1905],
#         [-0.0766, -0.3158, -0.3515, -0.2254],
#         ...,
#         [-0.0020,  0.3974,  0.0123, -0.3448],
#         [ 0.0831,  0.0301,  0.2025, -0.3015],
#         [-0.0452, -0.2938, -0.1895, -0.4559]], requires_grad=True)
# =======================================
# actor_critic.actor_fc1.weight : Parameter containing:
# tensor([[-0.2316,  0.2739, -0.1007, -0.3918],
#         [ 0.4685, -0.4545, -0.2888, -0.1344],
#         [ 0.1983,  0.2993, -0.1890,  0.2711],
#         ...,
#         [ 0.4253, -0.3699, -0.0451, -0.3162],
#         [-0.1304, -0.1343,  0.2468,  0.0368],
#         [-0.0313,  0.3430,  0.1764,  0.4266]], requires_grad=True)
# actor_critic.critic_fc2.weight : Parameter containing:
# tensor([[-0.4247, -0.4649, -0.4878,  0.2030],
#         [-0.1702,  0.2981, -0.3766,  0.1905],
#         [-0.0766, -0.3158, -0.3515, -0.2254],
#         ...,
#         [-0.0020,  0.3974,  0.0123, -0.3448],
#         [ 0.0831,  0.0301,  0.2025, -0.3015],
#         [-0.0452, -0.2938, -0.1895, -0.4559]], requires_grad=True)
# =======================================
# actor_critic.actor_fc1.weight : Parameter containing:
# tensor([[-0.2317,  0.2738, -0.1007, -0.3918],
#         [ 0.4685, -0.4545, -0.2887, -0.1344],
#         [ 0.1982,  0.2993, -0.1889,  0.2711],
#         ...,
#         [ 0.4253, -0.3699, -0.0450, -0.3161],
#         [-0.1304, -0.1343,  0.2468,  0.0368],
#         [-0.0314,  0.3429,  0.1764,  0.4266]], requires_grad=True)
# actor_critic.critic_fc2.weight : Parameter containing:
# tensor([[-0.4247, -0.4649, -0.4878,  0.2030],
#         [-0.1702,  0.2981, -0.3766,  0.1905],
#         [-0.0766, -0.3158, -0.3515, -0.2254],
#         ...,
#         [-0.0020,  0.3974,  0.0123, -0.3448],
#         [ 0.0831,  0.0301,  0.2025, -0.3015],
#         [-0.0452, -0.2938, -0.1895, -0.4559]], requires_grad=True)
# =======================================
# actor_critic.actor_fc1.weight : Parameter containing:
# tensor([[-0.2318,  0.2738, -0.1006, -0.3917],
#         [ 0.4685, -0.4545, -0.2887, -0.1344],
#         [ 0.1982,  0.2992, -0.1889,  0.2711],
#         ...,
#         [ 0.4252, -0.3700, -0.0450, -0.3161],
#         [-0.1304, -0.1343,  0.2468,  0.0368],
#         [-0.0314,  0.3429,  0.1763,  0.4266]], requires_grad=True)
# actor_critic.critic_fc2.weight : Parameter containing:
# tensor([[-0.4247, -0.4649, -0.4878,  0.2030],
#         [-0.1702,  0.2981, -0.3766,  0.1905],
#         [-0.0766, -0.3158, -0.3515, -0.2254],
#         ...,
#         [-0.0020,  0.3974,  0.0123, -0.3448],
#         [ 0.0831,  0.0301,  0.2025, -0.3015],
#         [-0.0452, -0.2938, -0.1895, -0.4559]], requires_grad=True)
# =======================================
# actor_critic.actor_fc1.weight : Parameter containing:
# tensor([[-0.2318,  0.2737, -0.1006, -0.3917],
#         [ 0.4685, -0.4545, -0.2887, -0.1344],
#         [ 0.1981,  0.2992, -0.1889,  0.2712],
#         ...,
#         [ 0.4252, -0.3701, -0.0449, -0.3160],
#         [-0.1304, -0.1343,  0.2468,  0.0368],
#         [-0.0314,  0.3430,  0.1763,  0.4265]], requires_grad=True)
# actor_critic.critic_fc2.weight : Parameter containing:
# tensor([[-0.4247, -0.4649, -0.4878,  0.2030],
#         [-0.1702,  0.2981, -0.3766,  0.1905],
#         [-0.0766, -0.3158, -0.3515, -0.2254],
#         ...,
#         [-0.0020,  0.3974,  0.0123, -0.3448],
#         [ 0.0831,  0.0301,  0.2025, -0.3015],
#         [-0.0452, -0.2938, -0.1895, -0.4559]], requires_grad=True)
# =======================================
# actor_critic.actor_fc1.weight : Parameter containing:
# tensor([[-0.2319,  0.2737, -0.1006, -0.3917],
#         [ 0.4685, -0.4545, -0.2887, -0.1343],
#         [ 0.1981,  0.2991, -0.1889,  0.2712],
#         ...,
#         [ 0.4252, -0.3701, -0.0448, -0.3160],
#         [-0.1304, -0.1343,  0.2468,  0.0368],
#         [-0.0314,  0.3429,  0.1763,  0.4265]], requires_grad=True)
# actor_critic.critic_fc2.weight : Parameter containing:
# tensor([[-0.4247, -0.4649, -0.4878,  0.2030],
#         [-0.1702,  0.2981, -0.3766,  0.1905],
#         [-0.0766, -0.3158, -0.3515, -0.2254],
#         ...,
#         [-0.0020,  0.3974,  0.0123, -0.3448],
#         [ 0.0831,  0.0301,  0.2025, -0.3015],
#         [-0.0452, -0.2938, -0.1895, -0.4559]], requires_grad=True)
# =======================================
# actor_critic.actor_fc1.weight : Parameter containing:
# tensor([[-0.2319,  0.2737, -0.1005, -0.3917],
#         [ 0.4685, -0.4545, -0.2887, -0.1344],
#         [ 0.1981,  0.2991, -0.1889,  0.2712],
#         ...,
#         [ 0.4252, -0.3701, -0.0448, -0.3160],
#         [-0.1304, -0.1343,  0.2468,  0.0368],
#         [-0.0314,  0.3430,  0.1763,  0.4265]], requires_grad=True)
# actor_critic.critic_fc2.weight : Parameter containing:
# tensor([[-0.4247, -0.4649, -0.4878,  0.2030],
#         [-0.1702,  0.2981, -0.3766,  0.1905],
#         [-0.0766, -0.3158, -0.3515, -0.2254],
#         ...,
#         [-0.0020,  0.3974,  0.0123, -0.3448],
#         [ 0.0831,  0.0301,  0.2025, -0.3015],
#         [-0.0452, -0.2938, -0.1895, -0.4559]], requires_grad=True)
# episode: 50, reward: 13.0, total length: 12, average length: 13.8
# =======================================
# actor_critic.actor_fc1.weight : Parameter containing:
# tensor([[-0.2318,  0.2737, -0.1005, -0.3917],
#         [ 0.4685, -0.4545, -0.2887, -0.1344],
#         [ 0.1982,  0.2992, -0.1889,  0.2712],
#         ...,
#         [ 0.4252, -0.3701, -0.0448, -0.3160],
#         [-0.1304, -0.1343,  0.2468,  0.0368],
#         [-0.0313,  0.3430,  0.1763,  0.4265]], requires_grad=True)
# actor_critic.critic_fc2.weight : Parameter containing:
# tensor([[-0.4247, -0.4649, -0.4878,  0.2030],
#         [-0.1702,  0.2981, -0.3766,  0.1905],
#         [-0.0766, -0.3158, -0.3515, -0.2254],
#         ...,
#         [-0.0020,  0.3974,  0.0123, -0.3448],
#         [ 0.0831,  0.0301,  0.2025, -0.3015],
#         [-0.0452, -0.2938, -0.1895, -0.4559]], requires_grad=True)
# =======================================
# actor_critic.actor_fc1.weight : Parameter containing:
# tensor([[-0.2318,  0.2737, -0.1005, -0.3917],
#         [ 0.4686, -0.4545, -0.2887, -0.1344],
#         [ 0.1982,  0.2991, -0.1889,  0.2712],
#         ...,
#         [ 0.4252, -0.3701, -0.0448, -0.3160],
#         [-0.1304, -0.1343,  0.2468,  0.0368],
#         [-0.0312,  0.3430,  0.1762,  0.4265]], requires_grad=True)
# actor_critic.critic_fc2.weight : Parameter containing:
# tensor([[-0.4247, -0.4649, -0.4878,  0.2030],
#         [-0.1702,  0.2981, -0.3766,  0.1905],
#         [-0.0766, -0.3158, -0.3515, -0.2254],
#         ...,
#         [-0.0020,  0.3974,  0.0123, -0.3448],
#         [ 0.0831,  0.0301,  0.2025, -0.3015],
#         [-0.0452, -0.2938, -0.1895, -0.4559]], requires_grad=True)
# =======================================
# actor_critic.actor_fc1.weight : Parameter containing:
# tensor([[-0.2317,  0.2736, -0.1005, -0.3916],
#         [ 0.4687, -0.4546, -0.2887, -0.1343],
#         [ 0.1983,  0.2991, -0.1889,  0.2712],
#         ...,
#         [ 0.4252, -0.3702, -0.0448, -0.3159],
#         [-0.1304, -0.1343,  0.2468,  0.0368],
#         [-0.0312,  0.3430,  0.1762,  0.4265]], requires_grad=True)
# actor_critic.critic_fc2.weight : Parameter containing:
# tensor([[-0.4247, -0.4649, -0.4878,  0.2030],
#         [-0.1702,  0.2981, -0.3766,  0.1905],
#         [-0.0766, -0.3158, -0.3515, -0.2254],
#         ...,
#         [-0.0020,  0.3974,  0.0123, -0.3448],
#         [ 0.0831,  0.0301,  0.2025, -0.3015],
#         [-0.0452, -0.2938, -0.1895, -0.4559]], requires_grad=True)
# =======================================
# actor_critic.actor_fc1.weight : Parameter containing:
# tensor([[-0.2316,  0.2736, -0.1005, -0.3916],
#         [ 0.4687, -0.4546, -0.2887, -0.1343],
#         [ 0.1983,  0.2991, -0.1889,  0.2712],
#         ...,
#         [ 0.4251, -0.3702, -0.0447, -0.3159],
#         [-0.1304, -0.1343,  0.2468,  0.0368],
#         [-0.0311,  0.3429,  0.1762,  0.4265]], requires_grad=True)
# actor_critic.critic_fc2.weight : Parameter containing:
# tensor([[-0.4247, -0.4649, -0.4878,  0.2030],
#         [-0.1702,  0.2981, -0.3766,  0.1905],
#         [-0.0766, -0.3158, -0.3515, -0.2254],
#         ...,
#         [-0.0020,  0.3974,  0.0123, -0.3448],
#         [ 0.0831,  0.0301,  0.2025, -0.3015],
#         [-0.0452, -0.2938, -0.1895, -0.4559]], requires_grad=True)
# =======================================
# actor_critic.actor_fc1.weight : Parameter containing:
# tensor([[-0.2316,  0.2736, -0.1005, -0.3916],
#         [ 0.4688, -0.4546, -0.2886, -0.1343],
#         [ 0.1984,  0.2990, -0.1888,  0.2713],
#         ...,
#         [ 0.4251, -0.3702, -0.0447, -0.3159],
#         [-0.1304, -0.1343,  0.2468,  0.0368],
#         [-0.0311,  0.3429,  0.1762,  0.4266]], requires_grad=True)
# actor_critic.critic_fc2.weight : Parameter containing:
# tensor([[-0.4247, -0.4649, -0.4878,  0.2030],
#         [-0.1702,  0.2981, -0.3766,  0.1905],
#         [-0.0766, -0.3158, -0.3515, -0.2254],
#         ...,
#         [-0.0020,  0.3974,  0.0123, -0.3448],
#         [ 0.0831,  0.0301,  0.2025, -0.3015],
#         [-0.0452, -0.2938, -0.1895, -0.4559]], requires_grad=True)
# =======================================
# actor_critic.actor_fc1.weight : Parameter containing:
# tensor([[-0.2315,  0.2735, -0.1004, -0.3915],
#         [ 0.4688, -0.4547, -0.2886, -0.1342],
#         [ 0.1985,  0.2990, -0.1888,  0.2713],
#         ...,
#         [ 0.4251, -0.3703, -0.0447, -0.3158],
#         [-0.1304, -0.1343,  0.2468,  0.0368],
#         [-0.0310,  0.3428,  0.1763,  0.4266]], requires_grad=True)
# actor_critic.critic_fc2.weight : Parameter containing:
# tensor([[-0.4247, -0.4649, -0.4878,  0.2030],
#         [-0.1702,  0.2981, -0.3766,  0.1905],
#         [-0.0766, -0.3158, -0.3515, -0.2254],
#         ...,
#         [-0.0020,  0.3974,  0.0123, -0.3448],
#         [ 0.0831,  0.0301,  0.2025, -0.3015],
#         [-0.0452, -0.2938, -0.1895, -0.4559]], requires_grad=True)
# =======================================
# actor_critic.actor_fc1.weight : Parameter containing:
# tensor([[-0.2315,  0.2735, -0.1004, -0.3915],
#         [ 0.4689, -0.4548, -0.2886, -0.1341],
#         [ 0.1985,  0.2989, -0.1888,  0.2714],
#         ...,
#         [ 0.4250, -0.3703, -0.0446, -0.3158],
#         [-0.1304, -0.1343,  0.2468,  0.0368],
#         [-0.0309,  0.3428,  0.1763,  0.4267]], requires_grad=True)
# actor_critic.critic_fc2.weight : Parameter containing:
# tensor([[-0.4247, -0.4649, -0.4878,  0.2030],
#         [-0.1702,  0.2981, -0.3766,  0.1905],
#         [-0.0766, -0.3158, -0.3515, -0.2254],
#         ...,
#         [-0.0020,  0.3974,  0.0123, -0.3448],
#         [ 0.0831,  0.0301,  0.2025, -0.3015],
#         [-0.0452, -0.2938, -0.1895, -0.4559]], requires_grad=True)
# =======================================
# actor_critic.actor_fc1.weight : Parameter containing:
# tensor([[-0.2314,  0.2734, -0.1004, -0.3914],
#         [ 0.4689, -0.4549, -0.2885, -0.1341],
#         [ 0.1986,  0.2989, -0.1888,  0.2715],
#         ...,
#         [ 0.4250, -0.3703, -0.0446, -0.3158],
#         [-0.1304, -0.1343,  0.2468,  0.0368],
#         [-0.0309,  0.3427,  0.1763,  0.4268]], requires_grad=True)
# actor_critic.critic_fc2.weight : Parameter containing:
# tensor([[-0.4247, -0.4649, -0.4878,  0.2030],
#         [-0.1702,  0.2981, -0.3766,  0.1905],
#         [-0.0766, -0.3158, -0.3515, -0.2254],
#         ...,
#         [-0.0020,  0.3974,  0.0123, -0.3448],
#         [ 0.0831,  0.0301,  0.2025, -0.3015],
#         [-0.0452, -0.2938, -0.1895, -0.4559]], requires_grad=True)
# =======================================
# actor_critic.actor_fc1.weight : Parameter containing:
# tensor([[-0.2314,  0.2733, -0.1003, -0.3913],
#         [ 0.4690, -0.4550, -0.2885, -0.1339],
#         [ 0.1986,  0.2988, -0.1887,  0.2715],
#         ...,
#         [ 0.4250, -0.3703, -0.0445, -0.3157],
#         [-0.1304, -0.1343,  0.2468,  0.0368],
#         [-0.0308,  0.3426,  0.1763,  0.4268]], requires_grad=True)
# actor_critic.critic_fc2.weight : Parameter containing:
# tensor([[-0.4247, -0.4649, -0.4878,  0.2030],
#         [-0.1702,  0.2981, -0.3766,  0.1905],
#         [-0.0766, -0.3158, -0.3515, -0.2254],
#         ...,
#         [-0.0020,  0.3974,  0.0123, -0.3448],
#         [ 0.0831,  0.0301,  0.2025, -0.3015],
#         [-0.0452, -0.2938, -0.1895, -0.4559]], requires_grad=True)
# =======================================
# actor_critic.actor_fc1.weight : Parameter containing:
# tensor([[-0.2313,  0.2733, -0.1003, -0.3913],
#         [ 0.4691, -0.4550, -0.2885, -0.1339],
#         [ 0.1987,  0.2988, -0.1887,  0.2716],
#         ...,
#         [ 0.4250, -0.3703, -0.0445, -0.3157],
#         [-0.1304, -0.1343,  0.2468,  0.0368],
#         [-0.0307,  0.3426,  0.1763,  0.4269]], requires_grad=True)
# actor_critic.critic_fc2.weight : Parameter containing:
# tensor([[-0.4247, -0.4649, -0.4878,  0.2030],
#         [-0.1702,  0.2981, -0.3766,  0.1905],
#         [-0.0766, -0.3158, -0.3515, -0.2254],
#         ...,
#         [-0.0020,  0.3974,  0.0123, -0.3448],
#         [ 0.0831,  0.0301,  0.2025, -0.3015],
#         [-0.0452, -0.2938, -0.1895, -0.4559]], requires_grad=True)
# episode: 60, reward: 16.0, total length: 15, average length: 19.4
# =======================================
# actor_critic.actor_fc1.weight : Parameter containing:
# tensor([[-0.2312,  0.2732, -0.1003, -0.3912],
#         [ 0.4692, -0.4551, -0.2885, -0.1338],
#         [ 0.1988,  0.2987, -0.1888,  0.2716],
#         ...,
#         [ 0.4250, -0.3703, -0.0445, -0.3157],
#         [-0.1304, -0.1343,  0.2468,  0.0368],
#         [-0.0306,  0.3425,  0.1762,  0.4269]], requires_grad=True)
# actor_critic.critic_fc2.weight : Parameter containing:
# tensor([[-0.4247, -0.4649, -0.4878,  0.2030],
#         [-0.1702,  0.2981, -0.3766,  0.1905],
#         [-0.0766, -0.3158, -0.3515, -0.2254],
#         ...,
#         [-0.0020,  0.3974,  0.0123, -0.3448],
#         [ 0.0831,  0.0301,  0.2025, -0.3015],
#         [-0.0452, -0.2938, -0.1895, -0.4559]], requires_grad=True)
# =======================================
# actor_critic.actor_fc1.weight : Parameter containing:
# tensor([[-0.2311,  0.2732, -0.1003, -0.3912],
#         [ 0.4693, -0.4551, -0.2885, -0.1338],
#         [ 0.1989,  0.2987, -0.1887,  0.2716],
#         ...,
#         [ 0.4250, -0.3703, -0.0445, -0.3157],
#         [-0.1304, -0.1343,  0.2468,  0.0368],
#         [-0.0305,  0.3425,  0.1762,  0.4270]], requires_grad=True)
# actor_critic.critic_fc2.weight : Parameter containing:
# tensor([[-0.4247, -0.4649, -0.4878,  0.2030],
#         [-0.1702,  0.2981, -0.3766,  0.1905],
#         [-0.0766, -0.3158, -0.3515, -0.2254],
#         ...,
# ...
# tensor([[-0.4247, -0.4649, -0.4878,  0.2030],
#         [-0.1702,  0.2981, -0.3766,  0.1905],
#         [-0.0766, -0.3158, -0.3515, -0.2254],
#         ...,
#         [-0.0020,  0.3974,  0.0123, -0.3448],
#         [ 0.0831,  0.0301,  0.2025, -0.3015],
#         [-0.0452, -0.2938, -0.1895, -0.4559]], requires_grad=True)
# =======================================
# actor_critic.actor_fc1.weight : Parameter containing:
# tensor([[-0.2324,  0.2725, -0.0760, -0.3806],
#         [ 0.4700, -0.4580, -0.3664, -0.1755],
#         [ 0.1740,  0.2978, -0.1065,  0.3128],
#         ...,
#         [ 0.4014, -0.4027, -0.1042, -0.3454],
#         [-0.1454, -0.1493,  0.2375,  0.0453],
#         [-0.0488,  0.3435,  0.2440,  0.4572]], requires_grad=True)
# actor_critic.critic_fc2.weight : Parameter containing:
# tensor([[-0.4247, -0.4649, -0.4878,  0.2030],
#         [-0.1702,  0.2981, -0.3766,  0.1905],
#         [-0.0766, -0.3158, -0.3515, -0.2254],
#         ...,
#         [-0.0020,  0.3974,  0.0123, -0.3448],
#         [ 0.0831,  0.0301,  0.2025, -0.3015],
#         [-0.0452, -0.2938, -0.1895, -0.4559]], requires_grad=True)
# =======================================
# actor_critic.actor_fc1.weight : Parameter containing:
# tensor([[-0.2326,  0.2725, -0.0761, -0.3807],
#         [ 0.4696, -0.4583, -0.3668, -0.1755],
#         [ 0.1739,  0.2978, -0.1062,  0.3128],
#         ...,
#         [ 0.4013, -0.4029, -0.1046, -0.3456],
#         [-0.1456, -0.1496,  0.2372,  0.0455],
#         [-0.0488,  0.3435,  0.2441,  0.4572]], requires_grad=True)
# actor_critic.critic_fc2.weight : Parameter containing:
# tensor([[-0.4247, -0.4649, -0.4878,  0.2030],
#         [-0.1702,  0.2981, -0.3766,  0.1905],
#         [-0.0766, -0.3158, -0.3515, -0.2254],
#         ...,
#         [-0.0020,  0.3974,  0.0123, -0.3448],
#         [ 0.0831,  0.0301,  0.2025, -0.3015],
#         [-0.0452, -0.2938, -0.1895, -0.4559]], requires_grad=True)
# =======================================
# actor_critic.actor_fc1.weight : Parameter containing:
# tensor([[-0.2327,  0.2724, -0.0762, -0.3807],
#         [ 0.4693, -0.4587, -0.3673, -0.1755],
#         [ 0.1736,  0.2978, -0.1059,  0.3128],
#         ...,
#         [ 0.4012, -0.4031, -0.1050, -0.3459],
#         [-0.1458, -0.1499,  0.2369,  0.0458],
#         [-0.0489,  0.3436,  0.2444,  0.4572]], requires_grad=True)
# actor_critic.critic_fc2.weight : Parameter containing:
# tensor([[-0.4247, -0.4649, -0.4878,  0.2030],
#         [-0.1702,  0.2981, -0.3766,  0.1905],
#         [-0.0766, -0.3158, -0.3515, -0.2254],
#         ...,
#         [-0.0020,  0.3974,  0.0123, -0.3448],
#         [ 0.0831,  0.0301,  0.2025, -0.3015],
#         [-0.0452, -0.2938, -0.1895, -0.4559]], requires_grad=True)
# =======================================
# actor_critic.actor_fc1.weight : Parameter containing:
# tensor([[-0.2328,  0.2724, -0.0763, -0.3807],
#         [ 0.4689, -0.4590, -0.3677, -0.1755],
#         [ 0.1734,  0.2979, -0.1056,  0.3128],
#         ...,
#         [ 0.4011, -0.4033, -0.1054, -0.3460],
#         [-0.1460, -0.1501,  0.2367,  0.0460],
#         [-0.0490,  0.3436,  0.2445,  0.4571]], requires_grad=True)
# actor_critic.critic_fc2.weight : Parameter containing:
# tensor([[-0.4247, -0.4649, -0.4878,  0.2030],
#         [-0.1702,  0.2981, -0.3766,  0.1905],
#         [-0.0766, -0.3158, -0.3515, -0.2254],
#         ...,
#         [-0.0020,  0.3974,  0.0123, -0.3448],
#         [ 0.0831,  0.0301,  0.2025, -0.3015],
#         [-0.0452, -0.2938, -0.1895, -0.4559]], requires_grad=True)
# =======================================
# actor_critic.actor_fc1.weight : Parameter containing:
# tensor([[-0.2329,  0.2723, -0.0763, -0.3807],
#         [ 0.4687, -0.4594, -0.3682, -0.1753],
#         [ 0.1732,  0.2981, -0.1054,  0.3127],
#         ...,
#         [ 0.4011, -0.4035, -0.1057, -0.3461],
#         [-0.1462, -0.1503,  0.2364,  0.0463],
#         [-0.0491,  0.3437,  0.2447,  0.4570]], requires_grad=True)
# actor_critic.critic_fc2.weight : Parameter containing:
# tensor([[-0.4247, -0.4649, -0.4878,  0.2030],
#         [-0.1702,  0.2981, -0.3766,  0.1905],
#         [-0.0766, -0.3158, -0.3515, -0.2254],
#         ...,
#         [-0.0020,  0.3974,  0.0123, -0.3448],
#         [ 0.0831,  0.0301,  0.2025, -0.3015],
#         [-0.0452, -0.2938, -0.1895, -0.4559]], requires_grad=True)
# =======================================
# actor_critic.actor_fc1.weight : Parameter containing:
# tensor([[-0.2330,  0.2723, -0.0764, -0.3806],
#         [ 0.4684, -0.4598, -0.3686, -0.1752],
#         [ 0.1731,  0.2982, -0.1051,  0.3126],
#         ...,
#         [ 0.4010, -0.4037, -0.1060, -0.3462],
#         [-0.1464, -0.1505,  0.2363,  0.0464],
#         [-0.0491,  0.3438,  0.2449,  0.4570]], requires_grad=True)
# actor_critic.critic_fc2.weight : Parameter containing:
# tensor([[-0.4247, -0.4649, -0.4878,  0.2030],
#         [-0.1702,  0.2981, -0.3766,  0.1905],
#         [-0.0766, -0.3158, -0.3515, -0.2254],
#         ...,
#         [-0.0020,  0.3974,  0.0123, -0.3448],
#         [ 0.0831,  0.0301,  0.2025, -0.3015],
#         [-0.0452, -0.2938, -0.1895, -0.4559]], requires_grad=True)
# =======================================
# actor_critic.actor_fc1.weight : Parameter containing:
# tensor([[-0.2330,  0.2722, -0.0765, -0.3806],
#         [ 0.4683, -0.4601, -0.3690, -0.1750],
#         [ 0.1729,  0.2984, -0.1047,  0.3125],
#         ...,
#         [ 0.4009, -0.4038, -0.1063, -0.3464],
#         [-0.1465, -0.1507,  0.2361,  0.0466],
#         [-0.0493,  0.3439,  0.2451,  0.4569]], requires_grad=True)
# actor_critic.critic_fc2.weight : Parameter containing:
# tensor([[-0.4247, -0.4649, -0.4878,  0.2030],
#         [-0.1702,  0.2981, -0.3766,  0.1905],
#         [-0.0766, -0.3158, -0.3515, -0.2254],
#         ...,
#         [-0.0020,  0.3974,  0.0123, -0.3448],
#         [ 0.0831,  0.0301,  0.2025, -0.3015],
#         [-0.0452, -0.2938, -0.1895, -0.4559]], requires_grad=True)
# =======================================
# actor_critic.actor_fc1.weight : Parameter containing:
# tensor([[-0.2330,  0.2722, -0.0767, -0.3806],
#         [ 0.4683, -0.4603, -0.3695, -0.1750],
#         [ 0.1726,  0.2986, -0.1044,  0.3124],
#         ...,
#         [ 0.4009, -0.4040, -0.1066, -0.3465],
#         [-0.1466, -0.1508,  0.2360,  0.0467],
#         [-0.0494,  0.3440,  0.2454,  0.4568]], requires_grad=True)
# actor_critic.critic_fc2.weight : Parameter containing:
# tensor([[-0.4247, -0.4649, -0.4878,  0.2030],
#         [-0.1702,  0.2981, -0.3766,  0.1905],
#         [-0.0766, -0.3158, -0.3515, -0.2254],
#         ...,
#         [-0.0020,  0.3974,  0.0123, -0.3448],
#         [ 0.0831,  0.0301,  0.2025, -0.3015],
#         [-0.0452, -0.2938, -0.1895, -0.4559]], requires_grad=True)
# episode: 560, reward: 64.0, total length: 63, average length: 98.3
# =======================================
# actor_critic.actor_fc1.weight : Parameter containing:
# tensor([[-0.2329,  0.2721, -0.0768, -0.3806],
#         [ 0.4683, -0.4605, -0.3699, -0.1750],
#         [ 0.1725,  0.2988, -0.1040,  0.3124],
#         ...,
#         [ 0.4008, -0.4042, -0.1070, -0.3466],
#         [-0.1466, -0.1508,  0.2359,  0.0469],
#         [-0.0496,  0.3441,  0.2456,  0.4568]], requires_grad=True)
# actor_critic.critic_fc2.weight : Parameter containing:
# tensor([[-0.4247, -0.4649, -0.4878,  0.2030],
#         [-0.1702,  0.2981, -0.3766,  0.1905],
#         [-0.0766, -0.3158, -0.3515, -0.2254],
#         ...,
#         [-0.0020,  0.3974,  0.0123, -0.3448],
#         [ 0.0831,  0.0301,  0.2025, -0.3015],
#         [-0.0452, -0.2938, -0.1895, -0.4559]], requires_grad=True)
# =======================================
# actor_critic.actor_fc1.weight : Parameter containing:
# tensor([[-0.2329,  0.2721, -0.0769, -0.3806],
#         [ 0.4683, -0.4607, -0.3703, -0.1750],
#         [ 0.1723,  0.2989, -0.1037,  0.3124],
#         ...,
#         [ 0.4007, -0.4043, -0.1073, -0.3470],
#         [-0.1468, -0.1510,  0.2359,  0.0471],
#         [-0.0497,  0.3442,  0.2459,  0.4568]], requires_grad=True)
# actor_critic.critic_fc2.weight : Parameter containing:
# tensor([[-0.4247, -0.4649, -0.4878,  0.2030],
#         [-0.1702,  0.2981, -0.3766,  0.1905],
#         [-0.0766, -0.3158, -0.3515, -0.2254],
#         ...,
#         [-0.0020,  0.3974,  0.0123, -0.3448],
#         [ 0.0831,  0.0301,  0.2025, -0.3015],
#         [-0.0452, -0.2938, -0.1895, -0.4559]], requires_grad=True)
# =======================================
# actor_critic.actor_fc1.weight : Parameter containing:
# tensor([[-0.2330,  0.2720, -0.0770, -0.3806],
#         [ 0.4682, -0.4609, -0.3707, -0.1750],
#         [ 0.1722,  0.2990, -0.1034,  0.3123],
#         ...,
#         [ 0.4006, -0.4044, -0.1076, -0.3473],
#         [-0.1469, -0.1512,  0.2359,  0.0473],
#         [-0.0498,  0.3442,  0.2460,  0.4568]], requires_grad=True)
# actor_critic.critic_fc2.weight : Parameter containing:
# tensor([[-0.4247, -0.4649, -0.4878,  0.2030],
#         [-0.1702,  0.2981, -0.3766,  0.1905],
#         [-0.0766, -0.3158, -0.3515, -0.2254],
#         ...,
#         [-0.0020,  0.3974,  0.0123, -0.3448],
#         [ 0.0831,  0.0301,  0.2025, -0.3015],
#         [-0.0452, -0.2938, -0.1895, -0.4559]], requires_grad=True)
# =======================================
# actor_critic.actor_fc1.weight : Parameter containing:
# tensor([[-0.2330,  0.2720, -0.0771, -0.3806],
#         [ 0.4680, -0.4610, -0.3710, -0.1750],
#         [ 0.1723,  0.2990, -0.1031,  0.3124],
#         ...,
#         [ 0.4002, -0.4045, -0.1079, -0.3476],
#         [-0.1471, -0.1514,  0.2359,  0.0474],
#         [-0.0497,  0.3442,  0.2462,  0.4568]], requires_grad=True)
# actor_critic.critic_fc2.weight : Parameter containing:
# tensor([[-0.4247, -0.4649, -0.4878,  0.2030],
#         [-0.1702,  0.2981, -0.3766,  0.1905],
#         [-0.0766, -0.3158, -0.3515, -0.2254],
#         ...,
#         [-0.0020,  0.3974,  0.0123, -0.3448],
#         [ 0.0831,  0.0301,  0.2025, -0.3015],
#         [-0.0452, -0.2938, -0.1895, -0.4559]], requires_grad=True)
# =======================================
# actor_critic.actor_fc1.weight : Parameter containing:
# tensor([[-0.2331,  0.2719, -0.0772, -0.3806],
#         [ 0.4677, -0.4611, -0.3713, -0.1750],
#         [ 0.1725,  0.2991, -0.1029,  0.3124],
#         ...,
#         [ 0.3998, -0.4046, -0.1081, -0.3479],
#         [-0.1472, -0.1515,  0.2359,  0.0475],
#         [-0.0496,  0.3442,  0.2464,  0.4569]], requires_grad=True)
# actor_critic.critic_fc2.weight : Parameter containing:
# tensor([[-0.4247, -0.4649, -0.4878,  0.2030],
#         [-0.1702,  0.2981, -0.3766,  0.1905],
#         [-0.0766, -0.3158, -0.3515, -0.2254],
#         ...,
#         [-0.0020,  0.3974,  0.0123, -0.3448],
#         [ 0.0831,  0.0301,  0.2025, -0.3015],
#         [-0.0452, -0.2938, -0.1895, -0.4559]], requires_grad=True)
# =======================================
# actor_critic.actor_fc1.weight : Parameter containing:
# tensor([[-0.2331,  0.2719, -0.0772, -0.3806],
#         [ 0.4675, -0.4613, -0.3715, -0.1750],
#         [ 0.1726,  0.2991, -0.1028,  0.3123],
#         ...,
#         [ 0.3995, -0.4046, -0.1084, -0.3482],
#         [-0.1473, -0.1517,  0.2359,  0.0476],
#         [-0.0495,  0.3442,  0.2465,  0.4569]], requires_grad=True)
# actor_critic.critic_fc2.weight : Parameter containing:
# tensor([[-0.4247, -0.4649, -0.4878,  0.2030],
#         [-0.1702,  0.2981, -0.3766,  0.1905],
#         [-0.0766, -0.3158, -0.3515, -0.2254],
#         ...,
#         [-0.0020,  0.3974,  0.0123, -0.3448],
#         [ 0.0831,  0.0301,  0.2025, -0.3015],
#         [-0.0452, -0.2938, -0.1895, -0.4559]], requires_grad=True)
# =======================================
# actor_critic.actor_fc1.weight : Parameter containing:
# tensor([[-0.2333,  0.2718, -0.0773, -0.3806],
#         [ 0.4672, -0.4615, -0.3717, -0.1749],
#         [ 0.1729,  0.2994, -0.1026,  0.3123],
#         ...,
#         [ 0.3992, -0.4047, -0.1086, -0.3484],
#         [-0.1474, -0.1518,  0.2359,  0.0477],
#         [-0.0493,  0.3444,  0.2466,  0.4568]], requires_grad=True)
# actor_critic.critic_fc2.weight : Parameter containing:
# tensor([[-0.4247, -0.4649, -0.4878,  0.2030],
#         [-0.1702,  0.2981, -0.3766,  0.1905],
#         [-0.0766, -0.3158, -0.3515, -0.2254],
#         ...,
#         [-0.0020,  0.3974,  0.0123, -0.3448],
#         [ 0.0831,  0.0301,  0.2025, -0.3015],
#         [-0.0452, -0.2938, -0.1895, -0.4559]], requires_grad=True)
# =======================================
# actor_critic.actor_fc1.weight : Parameter containing:
# tensor([[-0.2334,  0.2718, -0.0773, -0.3806],
#         [ 0.4670, -0.4616, -0.3718, -0.1748],
#         [ 0.1732,  0.2995, -0.1025,  0.3122],
#         ...,
#         [ 0.3990, -0.4046, -0.1087, -0.3487],
#         [-0.1475, -0.1519,  0.2359,  0.0478],
#         [-0.0491,  0.3445,  0.2467,  0.4568]], requires_grad=True)
# actor_critic.critic_fc2.weight : Parameter containing:
# tensor([[-0.4247, -0.4649, -0.4878,  0.2030],
#         [-0.1702,  0.2981, -0.3766,  0.1905],
#         [-0.0766, -0.3158, -0.3515, -0.2254],
#         ...,
#         [-0.0020,  0.3974,  0.0123, -0.3448],
#         [ 0.0831,  0.0301,  0.2025, -0.3015],
#         [-0.0452, -0.2938, -0.1895, -0.4559]], requires_grad=True)
# =======================================
# actor_critic.actor_fc1.weight : Parameter containing:
# tensor([[-0.2335,  0.2718, -0.0774, -0.3806],
#         [ 0.4669, -0.4618, -0.3720, -0.1746],
#         [ 0.1734,  0.2997, -0.1023,  0.3121],
#         ...,
#         [ 0.3988, -0.4046, -0.1088, -0.3489],
#         [-0.1476, -0.1520,  0.2359,  0.0479],
#         [-0.0489,  0.3446,  0.2468,  0.4567]], requires_grad=True)
# actor_critic.critic_fc2.weight : Parameter containing:
# tensor([[-0.4247, -0.4649, -0.4878,  0.2030],
#         [-0.1702,  0.2981, -0.3766,  0.1905],
#         [-0.0766, -0.3158, -0.3515, -0.2254],
#         ...,
#         [-0.0020,  0.3974,  0.0123, -0.3448],
#         [ 0.0831,  0.0301,  0.2025, -0.3015],
#         [-0.0452, -0.2938, -0.1895, -0.4559]], requires_grad=True)
# =======================================
# actor_critic.actor_fc1.weight : Parameter containing:
# tensor([[-0.2336,  0.2718, -0.0774, -0.3806],
#         [ 0.4668, -0.4618, -0.3722, -0.1746],
#         [ 0.1736,  0.2998, -0.1021,  0.3121],
#         ...,
#         [ 0.3986, -0.4045, -0.1090, -0.3492],
#         [-0.1476, -0.1521,  0.2359,  0.0480],
#         [-0.0488,  0.3446,  0.2469,  0.4567]], requires_grad=True)
# actor_critic.critic_fc2.weight : Parameter containing:
# tensor([[-0.4247, -0.4649, -0.4878,  0.2030],
#         [-0.1702,  0.2981, -0.3766,  0.1905],
#         [-0.0766, -0.3158, -0.3515, -0.2254],
#         ...,
#         [-0.0020,  0.3974,  0.0123, -0.3448],
#         [ 0.0831,  0.0301,  0.2025, -0.3015],
#         [-0.0452, -0.2938, -0.1895, -0.4559]], requires_grad=True)
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Input In [4], in <cell line: 1>()
#       1 if __name__ == "__main__":
#       2     env = gym.make("CartPole-v0")
# ----> 3     a2c(env)
#
# Input In [3], in a2c(env)
#      18 state = env.reset()
#      19 for steps in range(num_steps):
# ---> 20     value, policy_dist = actor_critic.forward(state)
#      21     value = value.detach().numpy()[0,0]
#      22     dist = policy_dist.detach().numpy()
#
# Input In [2], in ActorCritic.forward(self, state)
#      12 def forward(self, state):
#      13     state = Variable(torch.from_numpy(state).float().unsqueeze(0))
# ---> 14     value = F.relu(self.critic_linear1(state))
#      15     value = self.critic_linear2(value)
#      17     policy_dist = F.relu(self.actor_linear1(state))
#
# File D:\programs\anaconda\envs\maze_solver\lib\site-packages\torch\nn\modules\module.py:1110, in Module._call_impl(self, *input, **kwargs)
#    1106 # If we don't have any hooks, we want to skip the rest of the logic in
#    1107 # this function, and just call forward.
#    1108 if not (self._backward_hooks or self._forward_hooks or self._forward_pre_hooks or _global_backward_hooks
#    1109         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1110     return forward_call(*input, **kwargs)
#    1111 # Do not call functions when jit is used
#    1112 full_backward_hooks, non_full_backward_hooks = [], []
#
# File D:\programs\anaconda\envs\maze_solver\lib\site-packages\torch\nn\modules\linear.py:103, in Linear.forward(self, input)
#     102 def forward(self, input: Tensor) -> Tensor:
# --> 103     return F.linear(input, self.weight, self.bias)
#
# KeyboardInterrupt:
